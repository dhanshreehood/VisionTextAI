# %%
# !pip install ultralytics pytesseract pyttsx3
import cv2
from ultralytics import YOLO
from PIL import Image
import numpy as np
import torch
import clip
import pytesseract

# Load models
device = "cuda" if torch.cuda.is_available() else "cpu"
clip_model, preprocess = clip.load("ViT-B/32", device=device)
yolo_model = YOLO("yolov8n.pt")

# Candidate captions (you can expand this list)
candidates = ["a man", "a woman", "a car", "a dog", "a group of people", "a child", "a building", "a bike"]

# OCR
def extract_ocr(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    return pytesseract.image_to_string(gray).strip()

# Caption generator
def generate_clip_caption(frame):
    image_pil = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    image_input = preprocess(image_pil).unsqueeze(0).to(device)
    text_tokens = clip.tokenize(candidates).to(device)

    with torch.no_grad():
        image_features = clip_model.encode_image(image_input)
        text_features = clip_model.encode_text(text_tokens)
        logits_per_image, _ = clip_model(image_input, text_tokens)
        probs = logits_per_image.softmax(dim=-1).cpu().numpy()
    
    best_idx = np.argmax(probs)
    return candidates[best_idx]

# OpenCV camera loop
cap = cv2.VideoCapture(0)  # 0 for webcam

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # YOLO Detection
    yolo_results = yolo_model.predict(frame, verbose=False)[0]
    annotated_frame = yolo_results.plot()

    # CLIP Caption
    caption = generate_clip_caption(frame)

    # OCR
    ocr_text = extract_ocr(frame)

    # Overlay info
    cv2.putText(annotated_frame, f"Caption: {caption}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
    if ocr_text:
        cv2.putText(annotated_frame, f"OCR: {ocr_text[:50]}", (10, 60),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 1)

    # Show the frame
    cv2.imshow("VisionTextAI Live", annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Requirement already satisfied: ultralytics in /opt/anaconda3/lib/python3.12/site-packages (8.3.108)
# Requirement already satisfied: pytesseract in /opt/anaconda3/lib/python3.12/site-packages (0.3.13)
# Requirement already satisfied: pyttsx3 in /opt/anaconda3/lib/python3.12/site-packages (2.98)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (3.9.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (2.6.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (0.21.0)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/lib/python3.12/site-packages (from pytesseract) (24.1)
# Requirement already satisfied: pyobjc>=2.4 in /opt/anaconda3/lib/python3.12/site-packages (from pyttsx3) (11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: pyobjc-core==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-libdispatch==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-libxpc==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Accessibility==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AdServices==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AdSupport==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AVKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AVFoundation==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AVRouting==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Accounts==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AddressBook==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Automator==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-BackgroundAssets==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-BrowserEngineKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-BusinessChat==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CFNetwork==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CalendarStore==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CallKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Carbon==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Cinematic==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ClassKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CloudKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Cocoa==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Collaboration==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ColorSync==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Contacts==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ContactsUI==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreAudio==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreData==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreLocation==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreMedia==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreML==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreMotion==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreServices==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreText==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-DataDetection==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-DeviceDiscoveryExtension==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-DiscRecording==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-EventKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ExtensionKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-FileProvider==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-FSEvents==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-FinderSync==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-GameCenter==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-GameController==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-HealthKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Intents==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-IntentsUI==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-InstantMessage==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-IOBluetooth==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-IOBluetoothUI==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-IOSurface==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-KernelManagement==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-LaunchServices==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MailKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MapKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MediaExtension==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Metal==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MetalFX==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MetalKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MetricKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MLCompute==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ModelIO==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-NetFS==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Network==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-OSAKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-OSLog==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-PassKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-PencilKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-PHASE==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Photos==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-PhotosUI==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-PushKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Quartz==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ReplayKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SafetyKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SafariServices==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ScreenTime==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Security==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SearchKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ShazamKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Social==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Speech==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SpriteKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-StoreKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SyncServices==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-WebKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-GameKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-GameplayKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SceneKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SensitiveContentAnalysis==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SharedWithYouCore==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SharedWithYou==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ScreenCaptureKit==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Symbols==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-ThreadNetwork==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-UserNotifications==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Virtualization==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-Vision==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==11.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
